# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
tracks = pd.read_csv('../songs_artists_combined.csv')
artists = pd.read_csv('../artists_filtered.csv')
# artists['followers_log'] = np.log10(artists.followers + 1)

# %%
artists.head()
# Out:
#                 artist_id                      genres     artist_name  \
# 0  4sh4MHP7lhrSUakxwZzwqz  canadian singer-songwriter  Bruce Cockburn
# 1  1NZA6DefBtQo2PgcmBtnTg                        folk   Kate Campbell
# 2  0HjoyITAvSVktTCjXUa40Q                         emo           Rufio
# 3  3G7qoMSLvu9Pmb0xGtf9fl             christian metal           Bride
# 4  2bSugToVO8DavocRulW3Yj                    new wave        The Call
#
#    artist_followers  artist_popularity  artist_followers_log  val_first_pc
# 0           45674.0               48.0              4.659679      2.572477
# 1            2931.0               11.0              3.467164      0.276686
# 2           65405.0               40.0              4.815618      2.327519
# 3           23773.0               31.0              4.376102      1.678275
# 4           27690.0               36.0              4.442339      1.930843

# %%
tracks.head()
# Out:
#    track_number  danceability  energy  key  loudness  mode  speechiness  \
# 0             1         0.521   0.814    2    -7.903     1       0.0546
# 1             2         0.697   0.234    4   -14.984     1       0.0301
# 2             3         0.417   0.365    9   -12.711     0       0.0344
# 3             4         0.695   0.312    2   -13.338     1       0.0293
# 4             5         0.584   0.611    2    -9.104     1       0.0291
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0         0.230          0.130000     0.288    0.894  172.989       247293
# 1         0.523          0.003640     0.104    0.336  101.608       258600
# 2         0.741          0.000641     0.258    0.307  172.692       225867
# 3         0.793          0.014600     0.104    0.372  125.427       390667
# 4         0.139          0.000113     0.115    0.438  118.199       229533
#
#    time_signature  year  popularity
# 0             3.0  1994         8.0
# 1             4.0  1994        12.0
# 2             3.0  1994         9.0
# 3             4.0  1994        10.0
# 4             4.0  1994         6.0

# %% [raw]
# plt.scatter(data_mat[:,16] / np.std(data_mat[:,16]), data_mat[:, 1] / np.std(data_mat[:,1]), alpha= 0.2, s=0.6)

# %%
plt.figure(figsize=(16, 6))
sns.heatmap(tracks.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
tracks['is_popular'] = tracks['popularity'] > 20

# %%
import seaborn as sns
sns.pairplot(tracks.sample(10000), vars=['key', 'energy', 'year', 'duration_ms', 'danceability', 'loudness'], diag_kind='kde', hue='is_popular', diag_kws={"common_norm":False})
